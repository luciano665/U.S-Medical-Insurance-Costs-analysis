# %% [markdown]
# # U.S. Medical Insurance Costs
# # Main Goals for the Project:
#     #1. Differnece of average insurance cost in male and Female
#     #2. Difference in average insurance cost for Smoker and Non-Smoker
#     #3. Most commmon region comapare average cost compare to othe rregions
#     #4. Average BMI total and per sex and take average on each one
#     #5. More ideas later
#
#
# # Hypothesis
#     #The higher insurance cost is for males
#
#     #Higher insurance cost is for Smokers
#
#     #Southwest has a greater insurance cost
#
#     #BMI afffetcts Insurance cost

# %%
#import csv Library
import csv

# %% [markdown]
# # RELEVANT INFO OF CSV
#     #1. Column age from 19  to 50+
#     #2. Sex column female/male
#     #3. Number of Childer per person
#     #4. If person is smoker or non-smoker
#     #5. Region of origin southwest/northwest
#     #6. Insurance charge per person

# %%
#Empty lists to store vales from csv file base on variables
ages = []
sex = []
bmis = []
childrens = []
smoker = []
regions  = []
prices = []

# %%
#Function to open files and store in list created
def read_info(list_to_add, type_info):
    list_pre = []
    #open method use, read icsv file
    with open("insurance.csv") as insurance_file:

        insurance_read = csv.DictReader(insurance_file)

        for row in insurance_read:
            list_pre.append(row[type_info])
            list_to_add = list_pre

        return list_to_add

# %%
#Call functio and store info to new lists
ages_final = read_info(ages, "age")
#print(ages_final)
sex_final = read_info(sex, "sex")
#print(sex_final)
bmis_final = read_info(bmis, "bmi")
#print(bmis_final)
childrens_final = read_info(childrens, "children")
#print(childrens_final)
smoker_final = read_info(smoker, "smoker")
#print(smoker_final)
regions_final = read_info(regions, "region")
#print(regions_final)
costs_final = read_info(prices, "charges")
#print(costs_final)

# %% [markdown]
# # Average for numerical data
#     #Average of ages
#     #Average of insurance cost
#     #Average of BMI
#     #Average of number of Children

# %%
#Average func for data expressed as numbers
def average_list_float(arr):
    total_sum = 0
    if len(arr) == 0:
        return print("No data avialable to use " + str(arr))
    for i in range(len(arr)):
        total_sum += float(arr[i])
    
    total_average = total_sum / len(arr)
    return total_average

average_ages_final = round(average_list_float(ages_final), 3)
average_insurance_cost = (average_list_float(costs_final), 3)
average_bmi = (average_list_float(bmis_final), 3)
average_num_children = round(average_list_float(childrens_final), 3)
#print(average_num_children)
#print(average_insurance_cost)
#print(average_ages_num)
#print(average_bmi)

# %% [markdown]
# # Count for Smoker, non-Smokers, and sex gender

# %%
#Funtion for average of values that are not int but have two possible values
#sex, smoker and region
def ave_for_string(value1, value2, list_type):
    total_1 = 0
    total_2 = 0
    for i in list_type:
        if i == value1:
            total_1 += 1 
        elif i == value2:
            total_2 += 1
    
    list_final_with_info = []
    list_final_with_info.append(total_1)
    list_final_with_info.append(total_2)
    return list_final_with_info


smoker_count = ave_for_string("yes", "no", smoker_final)
smoker_y = smoker_count[0]
non_smoker = smoker_count[1]
print("The amount of Smoker is: " + str(smoker_y))
print("The amount of Non-Smokers is: " + str(non_smoker))
sex_count = ave_for_string("male", "female", sex_final)
male_count = sex_count[0]
female_count = sex_count[1]
print("The amount of males in the dataset is: " + str(male_count))
print("The amount of females in the dataset is: " + str(female_count))
#print(sex_count)
# Out:
# The amount of Smoker is: 274
# The amount of Non-Smokers is: 1064
# The amount of males in the dataset is: 676
# The amount of females in the dataset is: 662

# %% [markdown]
# # Difference between amount of different data
#     #Differenc between male and females
#     #Difference between smokers and non-smokers

# %%
#Difference in values that are not numerical
def difference_calc(value1 , value2, value3, value4):
    diffrence_total = abs(value1 - value2 - value4 - value3)
    return diffrence_total

#Where non-smoker > smokers 
difference_smokers = difference_calc(smoker_y, non_smoker, 0, 0)
#print(difference_smokers)
#Where  males count > female count
difference_sex = difference_calc(male_count, female_count, 0, 0)
#print(difference_sex)

# %%
#Create dictionary with key value as id from 1 to n elemenst and rest as list of values
#2 Main dictionaries base on region for southwest and northwest. Since both are unique 2 values for regions info
dict_southwest = {}
dict_northwest = {}
dict_northeast = {}
dict_southeast = {}
se_index = 1
ne_index = 1
sw_index = 1
nw_index = 1
zip_value = zip(ages_final, sex_final, bmis_final, childrens_final, smoker_final, regions_final, costs_final)

for info in zip_value:
    if info[5] == "southwest":
        dict_southwest[sw_index] = info
        sw_index += 1
    elif info[5] == "northwest":
        dict_northwest[nw_index] = info
        nw_index += 1
    elif info[5] == "southeast":
        dict_southeast[se_index] = info
        se_index += 1
    elif info[5] == "northeast":
        dict_northeast[ne_index] = info
        ne_index += 1

print("The length of NE is " + str(len(dict_northeast)))
print("The length of SE is " + str(len(dict_southeast)))
print("Teh length of SW is " + str(len(dict_southwest)))
print("The length of NW is " + str(len(dict_northwest)))
print("We conclude that there is more poeple from SE region in the data set. The values will be affected since there is more values for that region")
# Out:
# The length of NE is 324
# The length of SE is 364
# Teh length of SW is 325
# The length of NW is 325
# We conclude that there is more poeple from SE region in the data set. The values will be affected since there is more values for that region

# %% [markdown]
# # Analysis of numerical data on each region
#     #1. Get average insurance cost, bmi, children, smoker ,age and sex.
#     #2. Compare difference between average 2 regions and total average of all the data together
#     #3. For insurance cost, bmi, smokers, childrens

# %%
def average_by_region(dict, k): #K is the index where the data we want is, K=-1 in where insurance_cost is. 
    total = 0
    for i in dict.values():
        total += float(i[k])
    
    average_total = total / len(dict)
    
    return average_total

# %%
#Average insurance cost by region and total 
average_insurance_sw = round(average_by_region(dict_southwest, -1), 3)
print("The average insurance cost in the region SW is: " + str(average_insurance_sw))
average_insurance_nw = round(average_by_region(dict_northwest, -1), 3)
print("The average insurance cost in the region NW is: " + str(average_insurance_nw))
average_insurance_se = round(average_by_region(dict_southeast, -1), 3)
print("The average insurance cost in the region SE is: " + str(average_insurance_se))
average_insurance_ne = round(average_by_region(dict_northeast, -1), 3)
print("The average insurance cost in the region NE is: " + str(average_insurance_ne))
total_average_cost_4regions = round((average_insurance_sw + average_insurance_nw + average_insurance_se  + average_insurance_ne) / 4, 3)
print("The average insurance cost in the four regions is " + str(total_average_cost_4regions))
#Average BMI by Region and total 
average_bmi_sw = round(average_by_region(dict_southwest, 2), 3)
print("The average BMI in the region SW is: " + str(average_bmi_sw))
average_bmi_nw = round(average_by_region(dict_northwest, 2), 3)
print("The average BMI in the region NW is: " + str(average_bmi_nw))
average_bmi_se = round(average_by_region(dict_southeast, 2), 3)
print("The average BMI in the region SE is: " + str(average_bmi_se))
average_bmi_ne = round(average_by_region(dict_northeast, 2), 3)
print("The average BMI in the region NE is: " + str(average_bmi_ne))
total_average_bmi = round((average_bmi_sw + average_bmi_nw + average_bmi_se + average_bmi_ne) / 4, 3)
print("The average BMI in the four regions is " + str(total_average_bmi))
#Average Age by Region and total 
average_age_sw = round(average_by_region(dict_southwest, 0), 3)
print("The Average age in the region SW is: " + str(average_age_sw), 3)
average_age_nw = round(average_by_region(dict_northwest, 0), 3)
print("The Average age in the region NW is: " + str(average_age_nw), 3)
average_age_se = round(average_by_region(dict_southeast, 0), 3)
print("The Average age in the region SE is: " + str(average_age_se), 3)
average_age_ne = round(average_by_region(dict_northeast, 0), 3)
print("The Average age in the region NE is: " + str(average_age_ne), 3)
print("The total Average of ages is " + str(average_ages_final))
#Average Num of Children by children
average_children_sw = round(average_by_region(dict_southwest, 3))
print("The average num of Children is the SW region is: " + str(average_children_sw))
average_children_nw = round(average_by_region(dict_northwest, 3))
print("The average num of Children is the NW region is: " + str(average_children_nw))
average_children_se = round(average_by_region(dict_southeast, 3))
print("The average num of Children is the SE region is: " + str(average_children_se))
average_children_ne = round(average_by_region(dict_northeast, 3))
print("The average num of Children is the NE region is: " + str(average_children_se))
print("The Total average num of children in all regions is: " + str(round(average_num_children)))
# Out:
# The average insurance cost in the region SW is: 12346.937
# The average insurance cost in the region NW is: 12417.575
# The average insurance cost in the region SE is: 14735.411
# The average insurance cost in the region NE is: 13406.385
# The average insurance cost in the four regions is 13226.577
# The average BMI in the region SW is: 30.597
# The average BMI in the region NW is: 29.2
# The average BMI in the region SE is: 33.356
# The average BMI in the region NE is: 29.174
# The average BMI in the four regions is 30.582
# The Average age in the region SW is: 39.455 3
# The Average age in the region NW is: 39.197 3
# The Average age in the region SE is: 38.94 3
# The Average age in the region NE is: 39.269 3
# The total Average of ages is 39.207
# The average num of Children is the SW region is: 1
# The average num of Children is the NW region is: 1
# The average num of Children is the SE region is: 1
# The average num of Children is the NE region is: 1
# ...

# %% [markdown]
# # Difference average for non-numerical values
#     #Smokers and Non-Smokers
#     #Gender

# %%
#function for regions to get average for gender smoker and nono smoker
def for_smo_and_g(dict, indx ,k1, k2):
    total_males = 0
    total_females = 0
    total_smokers = 0
    total_nonSmokers = 0
    dict_gender = {}
    dict_smoke = {}
    for i in dict.values():
        if i[indx] == k1 and indx == 1:
            total_females += 1
        elif i[indx] == k2 and indx == 1:
            total_males += 1
        elif i[indx] == k1 and indx == 4:
            total_smokers +=1
        elif i[indx] == k2 and indx == 4:
            total_nonSmokers += 1
    
    if indx == 1:
        dict_gender["males"] = total_males
        #dict_gender["males_ave"] = round(total_males / len(dict))
        dict_gender["females"] = total_females
        #dict_gender["females_ave"] = round(total_females / len(dict))
        return dict_gender
    elif indx == 4:
        dict_smoke["Smokers"] = total_smokers
        #dict_smoke["Smoke_ave"] = round(total_smokers / len(dict))
        dict_smoke["Non_smokers"] = total_nonSmokers
        #dict_smoke["Non_smokers_ave"] = round(total_nonSmokers / len(dict))
        return dict_smoke

# %%
#Info for Gender and smokers/non
print("The total amount of males is: " + str(male_count) + " and for females is: " + str(female_count))
sex_info_sw = for_smo_and_g(dict_southwest, 1, "female", "male")
print("For the region SW the gender data is: " + str(sex_info_sw))
sex_info_nw = for_smo_and_g(dict_northwest, 1, "female", "male")
print("For the region NW the gender data is: " + str(sex_info_nw))
sex_info_se = for_smo_and_g(dict_southeast, 1, "female", "male")
print("For the region SE the gender data is: " + str(sex_info_se))
sex_info_ne = for_smo_and_g(dict_northeast, 1, "female", "male")
print("For the region NE the gender data is: " + str(sex_info_ne))
#For Smoker and Non-smokers
print("The total amount of smokers is: " + str(smoker_y) + " and for Non-Smkoers is: " + str(non_smoker))
smo_info_sw = for_smo_and_g(dict_southwest, 4, "yes", "no")
print("For the region SW the smokers data is: " + str(smo_info_sw))
smo_info_nw = for_smo_and_g(dict_northwest, 4, "yes", "no")
print("For the region NW the smokers data is: " + str(smo_info_nw))
smo_info_se = for_smo_and_g(dict_southeast, 4, "yes", "no")
print("For the region SE the smokers data is: " + str(smo_info_se))
smo_info_ne = for_smo_and_g(dict_northeast, 4, "yes", "no")
print("For the region NE the smokers data is: " + str(smo_info_ne))
# Out:
# The total amount of males is: 676 and for females is: 662
# For the region SW the gender data is: {'males': 163, 'females': 162}
# For the region NW the gender data is: {'males': 161, 'females': 164}
# For the region SE the gender data is: {'males': 189, 'females': 175}
# For the region NE the gender data is: {'males': 163, 'females': 161}
# The total amount of smokers is: 274 and for Non-Smkoers is: 1064
# For the region SW the smokers data is: {'Smokers': 58, 'Non_smokers': 267}
# For the region NW the smokers data is: {'Smokers': 58, 'Non_smokers': 267}
# For the region SE the smokers data is: {'Smokers': 91, 'Non_smokers': 273}
# For the region NE the smokers data is: {'Smokers': 67, 'Non_smokers': 257}

# %% [markdown]
# # Segmentation for insurance costs
#     #Segmentation base on smoker, non-smoker, with children and without childrens
#     #Get average of diffrent scenarions:
#         #Insurace cost of smokers and non-smokers only
#         #Insurance cost if ther eis childrens and if not
#         #Insurance cost of combination of smoker/non-smoter with childrens and without childrens
#     #This is segemented for each region, to compare correlation of costs but not causation

# %%
#Function to check de insurance cost for smokers/non-smokers and for people with childrens and not
def average_cost_for_diff_categ(dict, idx, k1_smoke, k2):
    list_smok = []
    list_nonS = []
    list_childrens = []
    list_not_childr = []
    list_smoke_withchil = []
    list_smoker_notchil = []
    list_nonS_withchill = []
    list_nonS_nochill = []

    for i in dict.values():
        if i[k1_smoke] == "yes":
            if idx == -1:
                list_smok.append(i[-1])
            elif i[idx] != '0' and idx == 3:
                list_smoke_withchil.append(i[-1])
            elif i[idx] == '0' and idx == 3:
                list_smoker_notchil.append(i[-1])
                
        elif i[k1_smoke] == "no":
            if idx == -1:
                list_nonS.append(i[-1])
            elif i[idx] != '0' and idx == 3:
                list_nonS_withchill.append(i[-1])
            elif i[idx] == '0' and idx == 3:
                list_nonS_nochill.append(i[-1])
        
        if idx == 3:
            if i[idx] != '0':
                list_childrens.append(i[-1])
            else:
                list_not_childr.append(i[-1])


    

    #For returning lists
    if k2 == 11:
        return list_smok
    elif k2 == 12:
        return list_nonS
    elif k2 == 13:
        return list_childrens
    elif k2 == 14:
        return list_not_childr
    elif k2 == 15:
        return list_nonS_withchill
    elif k2 == 16:
        return list_nonS_nochill
    elif k2 == 17:
        return list_smoke_withchil
    elif k2 == 18:
        return list_smoker_notchil

# %%
#Calculation of average for insurance cost base on characteristics we choose
#Calculation of isurnace cost for each region and for all region in general for smokers, non-smoker, with children, without children, smokers_withchildrne, smokers withourt childrens, non-smoker with/witout childrens
#For Region SW:
#1.Smokers and Non_smokers:
insurance_cost_of_smokers_sw = average_cost_for_diff_categ(dict_southwest, -1, 4, 11)
print("The insurance costs for " +str(len(insurance_cost_of_smokers_sw)) +" smokers is for the region SW is: " + str(insurance_cost_of_smokers_sw))
average_cost_smo_sw = round(average_list_float(insurance_cost_of_smokers_sw), 3)
print("The average insurance Cost for smokers in the region SW is : " + str(average_cost_smo_sw))
insurance_cost_nonsm_sw = average_cost_for_diff_categ(dict_southwest, -1, 4, 12)
print("The insurance costs for " +str(len(insurance_cost_nonsm_sw)) +" non-smokers in the region SW is: " + str(insurance_cost_nonsm_sw))
average_nosm_sw = round(average_list_float(insurance_cost_nonsm_sw), 3)
print("The average insurance cost fro non-smokers is: " + str(average_nosm_sw))
#2.With children and without children:
insurance_cost_w_child_sw = average_cost_for_diff_categ(dict_southwest, 3, 4, 13)
print("The insurance costs for " + str(len(insurance_cost_w_child_sw)) +  " people with childrens isn the region SW is: " + str(insurance_cost_w_child_sw))
average_cost_w_child_sw = round(average_list_float(insurance_cost_w_child_sw), 3)
print("The average insurance cost for people with childrens in the region SW is: "  + str(average_cost_w_child_sw))
insurance_cost_n_child_sw = average_cost_for_diff_categ(dict_southwest, 3, 4, 14)
print("The insurace costs for " + str(len(insurance_cost_n_child_sw))+" people with no childrens in the region SW is: " + str(insurance_cost_n_child_sw))
average_cost_n_child_sw = round(average_list_float(insurance_cost_n_child_sw), 2)
print("The average insurance cost for people without childrens in the region SW is: "  + str(average_cost_n_child_sw))
#3.For smokers with and without childrens
insurance_cost_smo_w_child_sw = average_cost_for_diff_categ(dict_southwest, 3, 4, 17)
print("The insurance costs for " +str(len(insurance_cost_smo_w_child_sw)) + " smokers with childrens for the region SW is: " + str(insurance_cost_smo_w_child_sw))
average_cost_smo_w_child_sw = round(average_list_float(insurance_cost_smo_w_child_sw), 3)
print("The average insurance cost of smoker with childrens for the region SW is: " + str(average_cost_smo_w_child_sw))
insurance_cost_smo_n_child_sw = average_cost_for_diff_categ(dict_southwest, 3, 4, 18)
print("The insurance costs for " +str(len(insurance_cost_smo_n_child_sw)) + " smokers with no childrens for te region SW is: "+ str(insurance_cost_smo_n_child_sw))
average_cost_smo_n_child_sw = round(average_list_float(insurance_cost_smo_n_child_sw), 3)
print("The average insurance cost of smoker without childrens for the region SW is: " + str(average_cost_smo_n_child_sw))
#4.For Non_Smokers with/out childrens
insurance_cost_nonsm_w_child_sw = average_cost_for_diff_categ(dict_southwest, 3, 4, 15)
print("The insurance costs for " + str(len(insurance_cost_nonsm_w_child_sw)) + " non-smokers with childrens for the region SW is: " + str(insurance_cost_nonsm_w_child_sw))
average_cost_nonsm_w_child_sw = round(average_list_float(insurance_cost_nonsm_w_child_sw), 3)
print("The average insurance cost of non-smoker with childrens for the region SW is: " + str(average_cost_nonsm_w_child_sw))
insurance_cost_nonsm_n_child_sw = average_cost_for_diff_categ(dict_southwest, 3, 4, 16)
print("The insurance costs for " +str(len(insurance_cost_nonsm_n_child_sw)) + " non-smokers with no childrens for te region SW is: "+ str(insurance_cost_nonsm_n_child_sw))
average_cost_nonsm_n_child_sw = round(average_list_float(insurance_cost_nonsm_n_child_sw), 3)
print("The average insurance cost for non-smoker for the region SW without childrens is " + str(average_cost_nonsm_n_child_sw))
# Out:
# The insurance costs for 58 smokers is for the region SW is: ['16884.924', '36837.467', '38711', '35585.576', '51194.55914', '48173.361', '23568.272', '39836.519', '47291.055', '15820.699', '17081.08', '48824.45', '34779.615', '47305.305', '42856.838', '16297.846', '34838.873', '35491.64', '47928.03', '13844.506', '36085.219', '18608.262', '37079.372', '22144.032', '25382.297', '17942.106', '36197.699', '21082.16', '39241.442', '23306.547', '40182.246', '40103.89', '44585.45587', '19040.876', '18259.216', '24520.264', '46113.511', '17496.306', '19933.458', '38998.546', '19199.944', '34472.841', '39727.614', '25309.489', '19023.26', '34166.273', '52590.82939', '22478.6', '38415.474', '41661.602', '20167.33603', '16232.847', '47403.88', '38344.566', '34828.654', '37829.7242', '33900.653', '36397.576']
# The average insurance Cost for smokers in the region SW is : 32269.063
# ...

# %%
#FOR THE REGION NW
#1.Smokers and Non_smokers:
insurance_cost_of_smokers_nw = average_cost_for_diff_categ(dict_northwest, -1, 4, 11)
#print("The insurance costs for " +str(len(insurance_cost_of_smokers_nw)) +" smokers is for the region NW is: " + str(insurance_cost_of_smokers_nw))
average_cost_smo_nw = round(average_list_float(insurance_cost_of_smokers_nw), 3)
print("The average insurance Cost for smokers in the region NW is : " + str(average_cost_smo_nw))
insurance_cost_nonsm_nw = average_cost_for_diff_categ(dict_northwest, -1, 4, 12)
#print("The insurance costs for " +str(len(insurance_cost_nonsm_nw)) +" non-smokers in the region SW is: " + str(insurance_cost_nonsm_nw))
average_nosm_nw = round(average_list_float(insurance_cost_nonsm_nw), 3)
print("The average insurance cost for non-smokers is: " + str(average_nosm_nw))
#2.With children and without children:
insurance_cost_w_child_nw = average_cost_for_diff_categ(dict_northwest, 3, 4, 13)
#print("The insurance costs for " + str(len(insurance_cost_w_child_nw)) +  " people with childrens isn the region NW is: " + str(insurance_cost_w_child_nw))
average_cost_w_child_nw = round(average_list_float(insurance_cost_w_child_nw), 3)
print("The average insurance cost for people with childrens in the region NW is: "  + str(average_cost_w_child_nw))
insurance_cost_n_child_nw = average_cost_for_diff_categ(dict_northwest, 3, 4, 14)
#print("The insurace costs for " + str(len(insurance_cost_n_child_nw))+" people with no childrens in the region NW is: " + str(insurance_cost_n_child_nw))
average_cost_n_child_nw = round(average_list_float(insurance_cost_n_child_nw), 2)
print("The average insurance cost for people without childrens in the region NW is: "  + str(average_cost_n_child_nw))
#3.For smokers with and without childrens
insurance_cost_smo_w_child_nw = average_cost_for_diff_categ(dict_northwest, 3, 4, 17)
#print("The insurance costs for " +str(len(insurance_cost_smo_w_child_nw)) + " smokers with childrens for the region NW is: " + str(insurance_cost_smo_w_child_nw))
average_cost_smo_w_child_nw = round(average_list_float(insurance_cost_smo_w_child_nw), 3)
print("The average insurance cost of smoker with childrens for the region NW is: " + str(average_cost_smo_w_child_nw))
insurance_cost_smo_n_child_nw = average_cost_for_diff_categ(dict_northwest, 3, 4, 18)
#print("The insurance costs for " +str(len(insurance_cost_smo_n_child_nw)) + " smokers with no childrens for te region NW is: "+ str(insurance_cost_smo_n_child_nw))
average_cost_smo_n_child_nw = round(average_list_float(insurance_cost_smo_n_child_nw), 3)
print("The average insurance cost of smoker without childrens for the region NW is: " + str(average_cost_smo_n_child_nw))
#4.For Non_Smokers with/out childrens
insurance_cost_nonsm_w_child_nw = average_cost_for_diff_categ(dict_northwest, 3, 4, 15)
#print("The insurance costs for " + str(len(insurance_cost_nonsm_w_child_sw)) + " non-smokers with childrens for the region NW is: " + str(insurance_cost_nonsm_w_child_nw))
average_cost_nonsm_w_child_nw = round(average_list_float(insurance_cost_nonsm_w_child_nw), 3)
print("The average insurance cost of non-smoker with childrens for the region NW is: " + str(average_cost_nonsm_w_child_nw))
insurance_cost_nonsm_n_child_nw = average_cost_for_diff_categ(dict_northwest, 3, 4, 16)
#print("The insurance costs for " +str(len(insurance_cost_nonsm_n_child_nw)) + " non-smokers with no childrens for te region NW is: "+ str(insurance_cost_nonsm_n_child_nw))
average_cost_nonsm_n_child_nw = round(average_list_float(insurance_cost_nonsm_n_child_nw), 3)
print("The average insurance cost for non-smoker without childrens for the region NW is: " + str(average_cost_nonsm_n_child_nw))
# Out:
# The average insurance Cost for smokers in the region NW is : 30192.003
# The average insurance cost for non-smokers is: 8556.464
# The average insurance cost for people with childrens in the region NW is: 13165.259
# The average insurance cost for people without childrens in the region NW is: 11324.37
# The average insurance cost of smoker with childrens for the region NW is: 31503.999
# The average insurance cost of smoker without childrens for the region NW is: 28333.342
# The average insurance cost of non-smoker with childrens for the region NW is: 9243.768
# The average insurance cost for non-smoker without childrens for the region NW is: 7544.599

# %%
#FOR THE REGION SE
#1.Smokers and Non_smokers:
insurance_cost_of_smokers_se = average_cost_for_diff_categ(dict_southeast, -1, 4, 11)
#print("The insurance costs for " +str(len(insurance_cost_of_smokers_se)) +" smokers is for the region SE is: " + str(insurance_cost_of_smokers_se))
average_cost_smo_se = round(average_list_float(insurance_cost_of_smokers_se), 3)
print("The average insurance Cost for smokers in the region SE is : " + str(average_cost_smo_se))
insurance_cost_nonsm_se = average_cost_for_diff_categ(dict_southeast, -1, 4, 12)
#print("The insurance costs for " +str(len(insurance_cost_nonsm_se)) +" non-smokers in the region SW is: " + str(insurance_cost_nonsm_se))
average_nosm_se = round(average_list_float(insurance_cost_nonsm_se), 3)
print("The average insurance cost for non-smokers is: " + str(average_nosm_se))
#2.With children and without children:
insurance_cost_w_child_se = average_cost_for_diff_categ(dict_southeast, 3, 4, 13)
#print("The insurance costs for " + str(len(insurance_cost_w_child_se)) +  " people with childrens isn the region SE is: " + str(insurance_cost_w_child_se))
average_cost_w_child_se = round(average_list_float(insurance_cost_w_child_se), 3)
print("The average insurance cost for people with childrens in the region SE is: "  + str(average_cost_w_child_se))
insurance_cost_n_child_se = average_cost_for_diff_categ(dict_southeast, 3, 4, 14)
#print("The insurace costs for " + str(len(insurance_cost_n_child_se))+" people with no childrens in the region SE is: " + str(insurance_cost_n_child_se))
average_cost_n_child_se = round(average_list_float(insurance_cost_n_child_se), 2)
print("The average insurance cost for people without childrens in the region SE is: "  + str(average_cost_n_child_se))
#3.For smokers with and without childrens
insurance_cost_smo_w_child_se = average_cost_for_diff_categ(dict_southeast, 3, 4, 17)
#print("The insurance costs for " +str(len(insurance_cost_smo_w_child_se)) + " smokers with childrens for the region SE is: " + str(insurance_cost_smo_w_child_se))
average_cost_smo_w_child_se = round(average_list_float(insurance_cost_smo_w_child_se), 3)
print("The average insurance cost of smoker with childrens for the region SW is: " + str(average_cost_smo_w_child_se))
insurance_cost_smo_n_child_se = average_cost_for_diff_categ(dict_southeast, 3, 4, 18)
#print("The insurance costs for " +str(len(insurance_cost_smo_n_child_se)) + " smokers with no childrens for te region SE is: "+ str(insurance_cost_smo_n_child_se))
average_cost_smo_n_child_se = round(average_list_float(insurance_cost_smo_n_child_se), 3)
print("The average insurance cost of smoker without childrens for the region SW is: " + str(average_cost_smo_n_child_se))
#4.For Non_Smokers with/out childrens
insurance_cost_nonsm_w_child_se = average_cost_for_diff_categ(dict_southeast, 3, 4, 15)
#print("The insurance costs for " + str(len(insurance_cost_nonsm_w_child_se)) + " non-smokers with childrens for the region SE is: " + str(insurance_cost_nonsm_w_child_se))
average_cost_nonsm_w_child_se = round(average_list_float(insurance_cost_nonsm_w_child_se), 3)
print("The average insurance cost of non-smoker with childrens for the region SE is: " + str(average_cost_nonsm_w_child_se))
insurance_cost_nonsm_n_child_se = average_cost_for_diff_categ(dict_southeast, 3, 4, 16)
#print("The insurance costs for " +str(len(insurance_cost_nonsm_n_child_se)) + " non-smokers with no childrens for te region SE is: "+ str(insurance_cost_nonsm_n_child_se))
average_cost_nonsm_n_child_se = round(average_list_float(insurance_cost_nonsm_n_child_se), 3)
print("The average insurance cost for non-smoker for the region SE without childrens is " + str(average_cost_nonsm_n_child_se))
# Out:
# The average insurance Cost for smokers in the region SE is : 34844.997
# The average insurance cost for non-smokers is: 8032.216
# The average insurance cost for people with childrens in the region SE is: 15058.166
# The average insurance cost for people without childrens in the region SE is: 14309.87
# The average insurance cost of smoker with childrens for the region SW is: 34319.117
# The average insurance cost of smoker without childrens for the region SW is: 35515.494
# The average insurance cost of non-smoker with childrens for the region SE is: 8761.317
# The average insurance cost for non-smoker for the region SE without childrens is 7060.082

# %%
#FOR THE REGION NE
#1.Smokers and Non_smokers:
insurance_cost_of_smokers_ne = average_cost_for_diff_categ(dict_northeast, -1, 4, 11)
#print("The insurance costs for " +str(len(insurance_cost_of_smokers_ne)) +" smokers is for the region NE is: " + str(insurance_cost_of_smokers_ne))
average_cost_smo_ne = round(average_list_float(insurance_cost_of_smokers_ne), 3)
print("The average insurance Cost for smokers in the region NW is : " + str(average_cost_smo_ne))
insurance_cost_nonsm_ne = average_cost_for_diff_categ(dict_northeast, -1, 4, 12)
#print("The insurance costs for " +str(len(insurance_cost_nonsm_ne)) +" non-smokers in the region NE is: " + str(insurance_cost_nonsm_ne))
average_nosm_ne = round(average_list_float(insurance_cost_nonsm_ne), 3)
print("The average insurance cost for non-smokers is: " + str(average_nosm_ne))
#2.With children and without children:
insurance_cost_w_child_ne = average_cost_for_diff_categ(dict_northeast, 3, 4, 13)
#print("The insurance costs for " + str(len(insurance_cost_w_child_ne)) +  " people with childrens isn the region NE is: " + str(insurance_cost_w_child_ne))
average_cost_w_child_ne = round(average_list_float(insurance_cost_w_child_ne), 3)
print("The average insurance cost for people with childrens in the region NE is: "  + str(average_cost_w_child_ne))
insurance_cost_n_child_ne = average_cost_for_diff_categ(dict_northeast, 3, 4, 14)
#print("The insurace costs for " + str(len(insurance_cost_n_child_ne))+" people with no childrens in the region NE is: " + str(insurance_cost_n_child_ne))
average_cost_n_child_ne = round(average_list_float(insurance_cost_n_child_ne), 2)
print("The average insurance cost for people without childrens in the region NE is: "  + str(average_cost_n_child_ne))
#3.For smokers with and without childrens
insurance_cost_smo_w_child_ne = average_cost_for_diff_categ(dict_northeast, 3, 4, 17)
#print("The insurance costs for " +str(len(insurance_cost_smo_w_child_ne)) + " smokers with childrens for the region NE is: " + str(insurance_cost_smo_w_child_ne))
average_cost_smo_w_child_ne = round(average_list_float(insurance_cost_smo_w_child_ne), 3)
#print("The average insurance cost of smoker with childrens for the region NW is: " + str(average_cost_smo_w_child_ne))
insurance_cost_smo_n_child_ne = average_cost_for_diff_categ(dict_northeast, 3, 4, 18)
#print("The insurance costs for " +str(len(insurance_cost_smo_n_child_ne)) + " smokers with no childrens for te region NE is: "+ str(insurance_cost_smo_n_child_ne))
average_cost_smo_n_child_ne = round(average_list_float(insurance_cost_smo_n_child_ne), 3)
print("The average insurance cost of smoker without childrens for the region NE is: " + str(average_cost_smo_n_child_ne))
#4.For Non_Smokers with/out childrens
insurance_cost_nonsm_w_child_ne = average_cost_for_diff_categ(dict_northeast, 3, 4, 15)
#print("The insurance costs for " + str(len(insurance_cost_nonsm_w_child_ne)) + " non-smokers with childrens for the region NE is: " + str(insurance_cost_nonsm_w_child_ne))
average_cost_nonsm_w_child_ne = round(average_list_float(insurance_cost_nonsm_w_child_ne), 3)
print("The average insurance cost of non-smoker with childrens for the region NE is: " + str(average_cost_nonsm_w_child_ne))
insurance_cost_nonsm_n_child_ne = average_cost_for_diff_categ(dict_northeast, 3, 4, 16)
#print("The insurance costs for " +str(len(insurance_cost_nonsm_n_child_ne)) + " non-smokers with no childrens for te region NW is: "+ str(insurance_cost_nonsm_n_child_ne))
average_cost_nonsm_n_child_ne = round(average_list_float(insurance_cost_nonsm_n_child_ne), 3)
print("The average insurance cost for non-smoker without childrens for the region NE is: " + str(average_cost_nonsm_n_child_ne))
# Out:
# The average insurance Cost for smokers in the region NW is : 29673.536
# The average insurance cost for non-smokers is: 9165.532
# The average insurance cost for people with childrens in the region NE is: 14884.625
# The average insurance cost for people without childrens in the region NE is: 11626.46
# The average insurance cost of smoker without childrens for the region NE is: 28167.026
# The average insurance cost of non-smoker with childrens for the region NE is: 10138.193
# The average insurance cost for non-smoker without childrens for the region NE is: 8072.292

# %% [markdown]
# # Data Visualitation

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data provided as lists
regions = ['Southwest', 'Northwest', 'Southeast', 'Northeast']
average_insurance_costs = [12346.937, 12417.575, 14735.411, 13406.385]
average_bmi = [30.597, 29.2, 33.356, 29.174]
smokers_count = [58, 58, 91, 67]
non_smokers_count = [267, 267, 273, 257]

# Creating a figure and a set of subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Average Insurance Costs by Region
axs[0, 0].bar(regions, average_insurance_costs, color='skyblue')
axs[0, 0].set_title('Average Insurance Costs by Region')
axs[0, 0].set_ylabel('Average Cost')
axs[0, 0].tick_params(axis='x', rotation=45)

# Average BMI by Region
axs[0, 1].bar(regions, average_bmi, color='lightgreen')
axs[0, 1].set_title('Average BMI by Region')
axs[0, 1].set_ylabel('BMI')
axs[0, 1].tick_params(axis='x', rotation=45)

# Smokers vs Non-Smokers Count by Region
x = np.arange(len(regions))  # the label locations
width = 0.35  # the width of the bars

rects1 = axs[1, 0].bar(x - width/2, smokers_count, width, label='Smokers', color='tomato')
rects2 = axs[1, 0].bar(x + width/2, non_smokers_count, width, label='Non-Smokers', color='gold')

# Add some text for labels, title and custom x-axis tick labels, etc.
axs[1, 0].set_title('Smokers and Non-Smokers Count by Region')
axs[1, 0].set_xticks(x)
axs[1, 0].set_xticklabels(regions)
axs[1, 0].legend()
axs[1, 0].tick_params(axis='x', rotation=45)

# Hiding the 4th plot (bottom right) as it's not used
fig.delaxes(axs[1][1])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert ages from strings to integers
ages_int = [int(age) for age in ages_final]

# Plot distribution of ages
plt.figure(figsize=(10, 6))
sns.histplot(ages_int, bins=30, kde=True)
plt.title('Distribution of Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Countplot for gender
plt.figure(figsize=(6, 4))
sns.countplot(x=sex_final)
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# Countplot for smokers
plt.figure(figsize=(6, 4))
sns.countplot(x=smoker_final)
plt.title('Smokers vs Non-Smokers')
plt.xlabel('Smoker')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming sex_final and smoker_final are your lists
data = {'Gender': sex_final, 'Smoker': smoker_final}
df = pd.DataFrame(data)

# Plot countplot for smoker status with a hue for gender
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Smoker', hue='Gender')
plt.title('Smoker Status Across Gender')
plt.xlabel('Smoker Status')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# ## Conclusion
#
# ### Gender Impact on Insurance Cost
# The analysis revealed a **distinct difference** in average insurance costs between genders. This supports the hypothesis that **gender plays a role in determining insurance costs**, with males speculated to have higher costs than females.
#
# ### Smokers vs. Non-Smokers
# Our findings clearly indicate that **smokers incur significantly higher insurance costs** compared to non-smokers. This trend holds true across all regions, highlighting the substantial financial impact of smoking on insurance premiums.
#
# ### Regional Differences
# The Southeast region was identified as having the **highest average insurance cost** among all regions analyzed. This confirms the hypothesis that geographic location influences insurance costs, with the Southeast standing out due to its higher costs.
#
# ### BMI Analysis
# While specific averages were not detailed, the analysis aimed to explore the impact of **BMI on insurance costs**. The expectation was that higher BMI levels would correlate with increased insurance costs, reflecting the health risks associated with higher BMI values.
#
# ### Insurance Cost Segmentation by Smoking Status and Children
# Segmenting insurance costs further revealed nuanced differences. **Smokers with and without children** and **non-smokers with and without children** displayed varied insurance costs, indicating the complexity of factors affecting insurance pricing.
#
# ### The Impact of Having Children on Insurance Costs
# The project also explored how having children affects insurance costs. Although detailed results were not provided, this aspect of the analysis offers insights into the influence of family size on insurance expenses.
#
# ---
#
# ### Enhancements and Future Directions
#
# This analysis has laid the groundwork for understanding the key factors influencing medical insurance costs in the U.S. Future studies could expand on this foundation by exploring additional variables such as age, specific health conditions, and employment status to gain a more comprehensive understanding of insurance cost determinants.
#
# ### Key Takeaways
#
# - **Smoking status** emerges as a significant factor in insurance cost determination.
# - Geographic **region** (specifically the Southeast) significantly influences average insurance costs.
# - The role of **gender** and **BMI** in determining insurance costs is evident, warranting further investigation.
